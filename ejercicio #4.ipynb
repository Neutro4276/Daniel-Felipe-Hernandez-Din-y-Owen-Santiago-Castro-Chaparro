# %%
# Ejercicio numero 4
edadjuan = 9
edadalber = (2/3) * edadjuan
edadana = (4/3) * edadjuan
edadmama = edadjuan+edadalber+edadana
print("Edad de Juan", edadjuan)
print("Edad de Alber", edadalber)
print("Edad de Ana", edadana)
print("Edad de Mama", edadmama)
# Out:
# Edad de Juan 9
# Edad de Alber 6.0
# Edad de Ana 12.0
# Edad de Mama 27.0
