# %%
# Ejercicio #14

numero = float(input("Ingrese un número: "))

cuadrado = numero ** 2
cubo = numero ** 3

print("El cuadrado es:", cuadrado)
print("El cubo es:", cubo)
# Out:
# Ingrese un número: 5
# El cuadrado es: 25.0
# El cubo es: 125.0
